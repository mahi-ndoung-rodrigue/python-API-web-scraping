# %%
                                               #INTRODUCTION

# %% [markdown]
# Les études en python pour débutant......
# Les devoirs et corrections..............

# %%
2+2

# %%
6/4

# %%
'HELLO WORLD'

# %%
6+4

# %%
import numpy as np

# %%
X = np.random.uniform(0,50,100)
Y = np.random.uniform(0,30,100)

# %%
X

# %%
Y

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X,Y,  'bo')

plt.Xlabel('X')
plt.Ylabel('Y')

plt.show()

# %% [markdown]
# équation de droite: $$Y = a X + b$$

# %% [markdown]
# CONCLUSION:

# %% [markdown]
# En somme, il était question de mettre en exerque la perception du logiciel python......

# %% [markdown]
# ![ASTG5368.JPG](attachment:ASTG5368.JPG)
