# %%
import pandas as pd

# %%
pd.read_csv
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]', sep=<no_default>, delimiter=None, header='infer', names=<no_default>, index_col=None, usecols=None, squeeze=None, prefix=<no_default>, mangle_dupe_cols=True, dtype: 'DtypeArg | None' = None, engine: 'CSVEngine | None' = None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=None, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression: 'CompressionOptions' = 'infer', thousands=None, decimal: 'str' = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, encoding_errors: 'str | None' = 'strict', dialect=None, error_bad_lines=None, warn_bad_lines=N
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %% [markdown]
# importation des données du titanic: il s' agit ici d'un fichier texte.

# %%
('titanic.csv')
# Out:
# 'titanic.csv'

# %%
df = pd.read_csv (filepath_or_buffer = 'titanic.csv')


df.head()

# %%
pd.read_csv('titanic.csv')

# %%
titanic_url = 'https://raw.githubusercontent.com/JosueAfouda/TUTORIALS/main/titanic.csv'

df = pd.read_csv (titanic_url)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.read_csv (filepath_or_buffer = titanic.csv)


df.head()

# %%
url = 'https://raw.githubusercontent.com/JosueAfouda/statistics-with-python/main/world_happiness.csv'

wh = pd.read_csv(url)

# %%
wh.head()
# Out:
#    Unnamed: 0      country  social_support  freedom  corruption  generosity  \
# 0           1      Finland             2.0      5.0         4.0        47.0
# 1           2      Denmark             4.0      6.0         3.0        22.0
# 2           3       Norway             3.0      3.0         8.0        11.0
# 3           4      Iceland             1.0      7.0        45.0         3.0
# 4           5  Netherlands            15.0     19.0        12.0         7.0
#
#    gdp_per_cap  life_exp  happiness_score
# 0        42400      81.8              155
# 1        48300      81.0              154
# 2        66300      82.6              153
# 3        47900      83.0              152
# 4        50500      81.8              151

# %% [markdown]
# on veut connaitre le nombre de lignes, colonnes de la dateframe;puis le nombre de variable distinctes de la colonnes Unnamed: 0

# %%
print(wh.shape)

print(wh['Unnamed: 0'].nunique())
# Out:
# (143, 9)
# 143

# %%
wh= pd.read_csv(url, index_col = 0)

wh.head()
# Out:
#        country  social_support  freedom  corruption  generosity  gdp_per_cap  \
# 1      Finland             2.0      5.0         4.0        47.0        42400
# 2      Denmark             4.0      6.0         3.0        22.0        48300
# 3       Norway             3.0      3.0         8.0        11.0        66300
# 4      Iceland             1.0      7.0        45.0         3.0        47900
# 5  Netherlands            15.0     19.0        12.0         7.0        50500
#
#    life_exp  happiness_score
# 1      81.8              155
# 2      81.0              154
# 3      82.6              153
# 4      83.0              152
# 5      81.8              151

# %%
wh.head()

# %% [markdown]
# importation des données du fichier 'annual_rainfall_dallas.csv'

# %%
url_rainfall= 'https://raw.githubusercontent.com/JosueAfouda/statistics-with-python/main/annual_rainfall_dallas.csv'


rainfall=pd.read_csv(url_rainfall)
rainfall.head()
# Out:
#    Year  Total
# 0  2019  34.52
# 1  2018  55.97
# 2  2017  36.62
# 3  2016  35.48
# 4  2015  62.61

# %%
print(rainfall.shape)
print(rainfall['Year'].nunique())
# Out:
# (121, 2)
# 121

# %%
rainfall=pd.read_csv( url_rainfall, index_col = 'Year' )

rainfall.head()
# Out:
#       Total
# Year
# 2019  34.52
# 2018  55.97
# 2017  36.62
# 2016  35.48
# 2015  62.61

# %%
dowjones.head()

# %%
from dict()

# %%
import pandas as pd
import seaborn as sns

# %%
titanic= sns.load_dataset('titanic')

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
titanic.tail(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
titanic.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
titanic.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked   class  \
# 463         0       2    male  48.0      0      0  13.000        S  Second
# 196         0       3    male   NaN      0      0   7.750        Q   Third
# 585         1       1  female  18.0      0      2  79.650        S   First
# 607         1       1    male  27.0      0      0  30.500        S   First
# 7           0       3    male   2.0      3      1  21.075        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 463    man        True  NaN  Southampton    no   True
# 196    man        True  NaN   Queenstown    no   True
# 585  woman       False    E  Southampton   yes  False
# 607    man        True  NaN  Southampton   yes   True
# 7    child       False  NaN  Southampton    no  False

# %%
titanic['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
titanic.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8644\2190932275.py in <module>
# ----> 1 titanic.describe()
#
# NameError: name 'titanic' is not defined

# %%
titanic.describe( include = 'all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic_age = titanic.fillna(value={'age': 0})

# %%
titanic_age.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic_embarked= titanic.fillna(value={'embarked':0})

# %%
titanic_embarked.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic_age2 = titanic.fillna(value={'age':titanic['age'].mean()})

# %%
titanic_age2.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic_sans_na=titanic.dropna()

# %%
titanic_sans_na.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
titanic_sans_na.shape
# Out:
# (182, 15)

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic_colonne_sans_na = titanic.drop(
    ['age','embarked','deck','embark_town'], axis=1
                                      )

# %%
titanic_colonne_sans_na .columns
# Out:
# Index(['survived', 'pclass', 'sex', 'sibsp', 'parch', 'fare', 'class', 'who',
#        'adult_male', 'alive', 'alone'],
#       dtype='object')

# %%
titanic_colonne_sans_na2 = titanic.dropna(axis = 1)

# %%
titanic_colonne_sans_na2.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'sibsp', 'parch', 'fare', 'class', 'who',
#        'adult_male', 'alive', 'alone'],
#       dtype='object')

# %%
titanic_colonne_sans_na2.isna().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# sibsp         0
# parch         0
# fare          0
# class         0
# who           0
# adult_male    0
# alive         0
# alone         0
# dtype: int64

# %%
titanic.rename(columns={'sex':'sexe'})

titanic.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8644\2443793506.py in <module>
# ----> 1 titanic.rename(columns={'sex':'sexe'})
#       2
#       3 titanic.head()
#
# NameError: name 'titanic' is not defined

# %%
titanic.groupby('pclass')['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8644\3288264824.py in <module>
# ----> 1 titanic.groupby('pclass')['age'].mean()
#
# NameError: name 'titanic' is not defined

# %%
stocks_price = {
    'app':[122333, 245.000, 3500.200],
    'goog':[35, 600, 700],
    'amz':[35,40,56],
    'fb':[3,4000, 67000098.6],
}

stocks_price
# Out:
# {'app': [122333, 245.0, 3500.2],
#  'goog': [35, 600, 700],
#  'amz': [35, 40, 56],
#  'fb': [3, 4000, 67000098.6]}

# %%
stocks_price['app']
# Out:
# [122333, 245.0, 3500.2]

# %%
stocks_price['fb']
# Out:
# [3, 4000, 67000098.6]

# %%
stocks_price['tesla']=[3, 200,  4000]

stocks_price
# Out:
# {'app': [122333, 245.0, 3500.2],
#  'goog': [12, 12, 12],
#  'amz': [444445, 40, 56],
#  'fb': [3, 4000, 67000098.6],
#  'tesla': [3, 200, 4000]}

# %%
stocks_price['goog']=[12, 12, 12]
stocks_price
# Out:
# {'app': [122333, 245.0, 3500.2],
#  'goog': [12, 12, 12],
#  'amz': [444445, 40, 56],
#  'fb': [3, 4000, 67000098.6],
#  'tesla': [3, 200, 4000]}

# %%
stocks_price['amz']=[444445, 40, 56]
stocks_price
# Out:
# {'app': [122333, 245.0, 3500.2],
#  'goog': [12, 12, 12],
#  'amz': [444445, 40, 56],
#  'fb': [3, 4000, 67000098.6],
#  'tesla': [3, 200, 4000]}

# %%
stocks_price.keys()
# Out:
# dict_keys(['app', 'goog', 'amz', 'fb', 'tesla'])

# %%
import pandas as pd

# %%
df=pd.DataFrame(stocks_price)
df
# Out:
#         app  goog     amz          fb  tesla
# 0  122333.0    12  444445         3.0      3
# 1     245.0    12      40      4000.0    200
# 2    3500.2    12      56  67000098.6   4000

# %%
df= df.T
df
# Out:
#               0       1           2
# app    122333.0   245.0      3500.2
# goog       12.0    12.0        12.0
# amz    444445.0    40.0        56.0
# fb          3.0  4000.0  67000098.6
# tesla       3.0   200.0      4000.0

# %%
df.columns=['prix','volume moyen action','niveau']
df
# Out:
#            prix  volume moyen action      niveau
# app    122333.0                245.0      3500.2
# goog       12.0                 12.0        12.0
# amz    444445.0                 40.0        56.0
# fb          3.0               4000.0  67000098.6
# tesla       3.0                200.0      4000.0

# %%
df.columns
# Out:
# Index(['prix', 'volume moyen action', 'niveau'], dtype='object')

# %%
clients = pd.read_csv('segmentation data.csv').head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3580\3360522440.py in <module>
# ----> 1 clients = pd.read_csv('segmentation data.csv').head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
